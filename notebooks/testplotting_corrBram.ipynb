# %%
import numpy as np
import numba as nb
from numba.typed import List
import pandas as pd
import itertools
from operator import itemgetter
import gc

from scipy.stats import norm, lognorm, truncnorm
import matplotlib.pyplot as plt
import seaborn as sns

from collections import Counter, deque
from sys import getsizeof
from sedgen.initialization import SedGen
from sedgen import initialization as ini
from sedgen import general as gen
from sedgen import preprocessing

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Load jupyter extension to reload packages before executing user code.
# https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html
# %load_ext autoreload
# Reload all packages (except those excluded by %aimport) every time 
# before executing the Python code typed.
# %autoreload 2

# %%
minerals = ["Q", "P", "K", "B", "O", "A"]

modal_mineralogy = np.array([[0.16331256, 0.46387757, 0.12683457, 0.05758711, 0.01078412, 0.17760407],   # AZ
                             [0.27453254, 0.40124204, 0.24993859, 0.02509231, 0.00454988, 0.04464465],   # CA-EW
                             [0.30591989, 0.38159713, 0.26209888, 0.0188256 , 0.00799247, 0.02356603],   # CA-NS
                             [0.19781274, 0.41766034, 0.16121575, 0.06478527, 0.00894429, 0.14958161],   # GR
                             [0.25983144, 0.46392506, 0.15827298, 0.04370113, 0.00689158, 0.06737782],   # MT
                             [0.22419158, 0.48490082, 0.05641885, 0.11571367, 0.00000001, 0.11877509]])  # WA

csds_AZ_means = np.array([0.120, 0.174, 0.112, 0.155, 0.066, 0.079])
csds_AZ_stds = np.array([0.359, 0.356, 0.455, 0.399, 0.328, 0.452])

csds_CA_EW_means = np.array([0.247, 0.333, 0.292, 0.212, 0.090, 0.127])
csds_CA_EW_stds = np.array([0.986, 0.640, 0.497, 0.889, 0.275, 0.502])

csds_CA_NS_means = np.array([0.309, 0.330, 0.244, 0.223, 0.120, 0.122])
csds_CA_NS_stds = np.array([0.823, 0.683, 0.817, 0.819, 0.554, 0.782])

csds_GR_means = np.array([0.244, 0.269, 0.222, 0.251, 0.059, 0.107])
csds_GR_stds = np.array([0.312, 0.450, 0.444, 0.262, 0.378, 0.313])

csds_MT_means = np.array([0.220, 0.227, 0.160, 0.153, 0.078, 0.075])
csds_MT_stds = np.array([0.472, 0.415, 0.344, 0.363, 0.315, 0.599])

csds_WA_means = np.array([0.342, 0.385, 0.241, 0.481, 0.001, 0.130])
csds_WA_stds = np.array([0.542, 0.478, 0.386, 0.467, 0.001, 0.494])

print(modal_mineralogy[1])
# Out:
# [0.27453254 0.40124204 0.24993859 0.02509231 0.00454988 0.04464465]

# %%
datapoints_AZ = np.zeros(4)
lrs_AZ = np.array([100, 1000, 10000, 100000])
par_rock = 1e9

for i, lr in enumerate(lrs_AZ):
    temp = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate=lr, discretization_init=False, timed=True)
    datapoints_AZ[i] = np.sum(temp.simulated_volume) / par_rock
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 47.3572 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 90.0317 seconds
# Counting interfaces...  Done in 1.0312 seconds
# Correcting interface arrays for consistency...
# too much Q 10
# too few P -1
# too few K -3
# too few B -3
# too few O -1
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.1440 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 41.1602 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 89.4101 seconds
# Counting interfaces...  Done in 0.9555 seconds
# Correcting interface arrays for consistency...
# all good Q 0
# too few P -1
# all good K 0
# too much B 1
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.0838 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 42.1957 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 87.7630 seconds
# Counting interfaces...  Done in 0.9135 seconds
# Correcting interface arrays for consistency...
# all good Q 0
# too much P 1
# too few K -1
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.0668 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 112.4426 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 90.4010 seconds
# Counting interfaces...  Done in 2.0280 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# all good P 0
# too few K -1
# all good B 0
# too few O -1
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.5167 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---

# %%
par_rock = 1e9
data1 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 46.1328 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 146.7812 seconds
# Counting interfaces...  Done in 1.0014 seconds
# Correcting interface arrays for consistency...
# too much Q 10
# too few P -1
# too few K -3
# too few B -3
# too few O -1
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.2155 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 44.3434 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 90.4951 seconds
# Counting interfaces...  Done in 0.9762 seconds
# Correcting interface arrays for consistency...
# all good Q 0
# too few P -1
# all good K 0
# too much B 1
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.0376 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 50.9381 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 109.8811 seconds
# Counting interfaces...  Done in 0.9247 seconds
# Correcting interface arrays for consistency...
# all good Q 0
# too much P 1
# too few K -1
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.1158 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 113.2007 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 91.7402 seconds
# Counting interfaces...  Done in 0.9488 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# all good P 0
# too few K -1
# all good B 0
# too few O -1
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 6.0732 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---

# %%
from sedgen import fit_functions
from scipy.optimize import curve_fit

# %%
xdata = lrs_AZ
ydata = datapoints_AZ
opt, cov = curve_fit(fit_functions.power_law_fit, np.log10(xdata), ydata, maxfev=10000)

# %%
opt
# Out:
# array([ 5.80001871e+01, -5.69725250e+01,  3.39350511e-04])

# %%
logar = np.log10(lrs_AZ)
print(logar)

plt.plot(logar, datapoints_AZ,'ro')
plt.plot(np.log10(xdata), fit_functions.power_law_fit(np.log10(xdata), *opt))
plt.xlabel("Learning rate (log10)")
plt.ylabel("Model volume ratio")
plt.show();
# Out:
# [2. 3. 4. 5.]

# %%
x = np.array([100,1000,10000,100000])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4])
logar = np.log10(x)
print(logar)

plt.plot(logar,y,'ro')
# Out:
# [2. 3. 4. 5.]

# %%
par_rock = 1e8
data1 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
x = np.array([100,1000,10000,100000])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4])
logar = np.log10(x)
print(logar)

plt.plot(logar,y,'ro')
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 3.9512 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 22.0391 seconds
# Counting interfaces...  Done in 0.0958 seconds
# Correcting interface arrays for consistency...
# too much Q 4
# too few P -2
# all good K 0
# too few B -1
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.6282 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 4.8253 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 9.2710 seconds
# Counting interfaces...  Done in 0.0942 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# all good P 0
# all good K 0
# all good B 0
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.6151 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 12.6970 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 8.1902 seconds
# Counting interfaces...  Done in 0.0889 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# too few P -2
# all good K 0
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.6731 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 75.5491 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 8.6127 seconds
# Counting interfaces...  Done in 0.0914 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# too few P -1
# all good K 0
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.5679 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# [2. 3. 4. 5.]

# %%
par_rock = 1e7
data1 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 500, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
x = np.array([500,1000,10000,100000])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4])
logar = np.log10(x)
print(logar)

plt.plot(logar,y,'ro')
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.6910 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.7561 seconds
# Counting interfaces...  Done in 0.0093 seconds
# Correcting interface arrays for consistency...
# too much Q 7
# too few P -4
# too few K -1
# all good B 0
# too few O -2
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0503 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.9397 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.7531 seconds
# Counting interfaces...  Done in 0.0082 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# too few P -1
# all good K 0
# all good B 0
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0580 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 5.0876 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.7744 seconds
# Counting interfaces...  Done in 0.0081 seconds
# Correcting interface arrays for consistency...
# too much Q 13
# too few P -6
# too few K -2
# too few B -2
# too few O -2
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0561 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 43.5484 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.8699 seconds
# Counting interfaces...  Done in 0.0095 seconds
# Correcting interface arrays for consistency...
# too much Q 4
# too few P -1
# too few K -1
# all good B 0
# all good O 0
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0605 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# [2.69897 3.      4.      5.     ]

# %%
par_rock = 1e7
data1 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
data5 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 250, discretization_init = False, timed = True)
datapunt5 = np.sum(data5.simulated_volume)/par_rock
data6 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 350, discretization_init = False, timed = True)
datapunt6 = np.sum(data6.simulated_volume)/par_rock
data7 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 450, discretization_init = False, timed = True)
datapunt7 = np.sum(data7.simulated_volume)/par_rock
data8 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 550, discretization_init = False, timed = True)
datapunt8 = np.sum(data8.simulated_volume)/par_rock
data9 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 650, discretization_init = False, timed = True)
datapunt9 = np.sum(data9.simulated_volume)/par_rock
data10 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 750, discretization_init = False, timed = True)
datapunt10 = np.sum(data10.simulated_volume)/par_rock
data11 = SedGen(minerals, par_rock, modal_mineralogy[0], csds_AZ_means, csds_AZ_stds, learning_rate = 850, discretization_init = False, timed = True)
datapunt11 = np.sum(data11.simulated_volume)/par_rock



x = np.array([100,1000,10000,100000,250,350,450,550,650,750,850])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4, datapunt5, datapunt6 ,datapunt7 ,datapunt8, datapunt9, datapunt10, datapunt11])
logar = np.log10(x)
print(logar)

plt.plot(logar,y,'ro')
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.4568 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.8039 seconds
# Counting interfaces...  Done in 0.0090 seconds
# Correcting interface arrays for consistency...
# too much Q 3
# too few P -2
# too much K 1
# all good B 0
# all good O 0
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0541 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.9494 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.8060 seconds
# Counting interfaces...  Done in 0.0090 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# too few P -1
# all good K 0
# all good B 0
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0546 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 5.0473 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.7738 seconds
# Counting interfaces...  Done in 0.0080 seconds
# Correcting interface arrays for consistency...
# too much Q 13
# too few P -6
# too few K -2
# too few B -2
# too few O -2
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0526 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 42.0835 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.9003 seconds
# Counting interfaces...  Done in 0.0095 seconds
# Correcting interface arrays for consistency...
# too much Q 4
# too few P -1
# too few K -1
# all good B 0
# all good O 0
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0579 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.5942 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.9266 seconds
# Counting interfaces...  Done in 0.0103 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# too few P -1
# all good K 0
# too much B 1
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0653 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.7780 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.9067 seconds
# Counting interfaces...  Done in 0.0093 seconds
# Correcting interface arrays for consistency...
# too much Q 10
# too few P -6
# too few K -1
# all good B 0
# too few O -2
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0613 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.7296 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.8510 seconds
# Counting interfaces...  Done in 0.0091 seconds
# Correcting interface arrays for consistency...
# too much Q 16
# too few P -8
# too few K -1
# too few B -3
# too few O -1
# too few A -3
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0594 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.8247 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.9522 seconds
# Counting interfaces...  Done in 0.0119 seconds
# Correcting interface arrays for consistency...
# too much Q 3
# too few P -2
# all good K 0
# all good B 0
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0626 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.0180 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 1.0652 seconds
# Counting interfaces...  Done in 0.0093 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# too few P -1
# all good K 0
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0584 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.9872 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.9134 seconds
# Counting interfaces...  Done in 0.0089 seconds
# Correcting interface arrays for consistency...
# too much Q 5
# too few P -2
# too few K -1
# all good B 0
# too few O -1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0571 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.9575 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.8231 seconds
# Counting interfaces...  Done in 0.0085 seconds
# Correcting interface arrays for consistency...
# too much Q 2
# too few P -1
# all good K 0
# too much B 1
# too few O -1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0553 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# [2.         3.         4.         5.         2.39794001 2.54406804
#  2.65321251 2.74036269 2.81291336 2.87506126 2.92941893]

# %%
par_rock = 1e7

data1 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 100, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
data5 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 250, discretization_init = False, timed = True)
datapunt5 = np.sum(data5.simulated_volume)/par_rock
data6 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 350, discretization_init = False, timed = True)
datapunt6 = np.sum(data6.simulated_volume)/par_rock
data7 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 450, discretization_init = False, timed = True)
datapunt7 = np.sum(data7.simulated_volume)/par_rock
data8 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 550, discretization_init = False, timed = True)
datapunt8 = np.sum(data8.simulated_volume)/par_rock
data9 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 650, discretization_init = False, timed = True)
datapunt9 = np.sum(data9.simulated_volume)/par_rock
data10 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 750, discretization_init = False, timed = True)
datapunt10 = np.sum(data10.simulated_volume)/par_rock
data11 = SedGen(minerals, par_rock, modal_mineralogy[5], csds_WA_means, csds_WA_stds, learning_rate = 850, discretization_init = False, timed = True)
datapunt11 = np.sum(data11.simulated_volume)/par_rock



x = np.array([100, 1000,10000,100000,250,350,450,550,650,750,850])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4, datapunt5, datapunt6 ,datapunt7 ,datapunt8, datapunt9, datapunt10, datapunt11])
logar = np.log10(x)
print(y)

print(logar)

plt.plot(logar,y,'ro')
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.0852 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.2426 seconds
# Counting interfaces...  Done in 0.0026 seconds
# Correcting interface arrays for consistency...
# too few Q -4
# too much P 1
# too much K 1
# too much B 2
# too few O -1
# too much A 1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0133 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.2675 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1652 seconds
# Counting interfaces...  Done in 0.0017 seconds
# Correcting interface arrays for consistency...
# too much Q 11
# too few P -2
# all good K 0
# too few B -1
# too few O -5
# too few A -3
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0122 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.0790 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1566 seconds
# Counting interfaces...  Done in 0.0016 seconds
# Correcting interface arrays for consistency...
# too much Q 12
# too few P -6
# all good K 0
# all good B 0
# too few O -4
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0095 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 7.9989 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1760 seconds
# Counting interfaces...  Done in 0.0018 seconds
# Correcting interface arrays for consistency...
# too much Q 11
# too few P -2
# too few K -2
# all good B 0
# too few O -4
# too few A -3
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0107 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.1013 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1957 seconds
# Counting interfaces...  Done in 0.0025 seconds
# Correcting interface arrays for consistency...
# too much Q 3
# too few P -1
# too few K -1
# all good B 0
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0121 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.1189 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.2112 seconds
# Counting interfaces...  Done in 0.0026 seconds
# Correcting interface arrays for consistency...
# too much Q 13
# too few P -2
# too few K -1
# all good B 0
# too few O -9
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0165 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.1377 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1807 seconds
# Counting interfaces...  Done in 0.0020 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# too few P -1
# all good K 0
# too much B 1
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0136 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.1301 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1681 seconds
# Counting interfaces...  Done in 0.0018 seconds
# Correcting interface arrays for consistency...
# too much Q 5
# all good P 0
# too few K -1
# too much B 1
# too few O -4
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0096 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.1989 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1772 seconds
# Counting interfaces...  Done in 0.0020 seconds
# Correcting interface arrays for consistency...
# too much Q 19
# too few P -6
# too few K -1
# all good B 0
# too few O -9
# too few A -3
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0109 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.2498 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1702 seconds
# Counting interfaces...  Done in 0.0018 seconds
# Correcting interface arrays for consistency...
# too much Q 20
# too few P -3
# too few K -2
# too few B -1
# too few O -10
# too few A -4
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0093 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 0.2579 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 0.1726 seconds
# Counting interfaces...  Done in 0.0021 seconds
# Correcting interface arrays for consistency...
# too much Q 34
# too few P -7
# too few K -6
# all good B 0
# too few O -9
# too few A -12
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.0106 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# [2.35400651 1.00280583 1.00187568 1.00191024 1.23759326 1.10781295
#  1.0599498  1.02108408 1.00062898 1.00177353 1.00163541]
# [2.         3.         4.         5.         2.39794001 2.54406804
#  2.65321251 2.74036269 2.81291336 2.87506126 2.92941893]

# %%
par_rock = 1e8

data1 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 100, discretization_init = False, timed = True)
datapunt1 = np.sum(data1.simulated_volume)/par_rock
data2 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 1000, discretization_init = False, timed = True)
datapunt2 = np.sum(data2.simulated_volume)/par_rock
data3 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 10000, discretization_init = False, timed = True)
datapunt3 = np.sum(data3.simulated_volume)/par_rock
data4 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 100000, discretization_init = False, timed = True)
datapunt4 = np.sum(data4.simulated_volume)/par_rock
data5 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 250, discretization_init = False, timed = True)
datapunt5 = np.sum(data5.simulated_volume)/par_rock
data6 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 350, discretization_init = False, timed = True)
datapunt6 = np.sum(data6.simulated_volume)/par_rock
data7 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 450, discretization_init = False, timed = True)
datapunt7 = np.sum(data7.simulated_volume)/par_rock
data8 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 550, discretization_init = False, timed = True)
datapunt8 = np.sum(data8.simulated_volume)/par_rock
data9 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 650, discretization_init = False, timed = True)
datapunt9 = np.sum(data9.simulated_volume)/par_rock
data10 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 750, discretization_init = False, timed = True)
datapunt10 = np.sum(data10.simulated_volume)/par_rock
data11 = SedGen(minerals, par_rock, modal_mineralogy[4], csds_MT_means, csds_MT_stds, learning_rate = 850, discretization_init = False, timed = True)
datapunt11 = np.sum(data11.simulated_volume)/par_rock



x = np.array([100, 1000,10000,100000,250,350,450,550,650,750,850])

y = np.array([datapunt1, datapunt2, datapunt3, datapunt4, datapunt5, datapunt6 ,datapunt7 ,datapunt8, datapunt9, datapunt10, datapunt11])
logar = np.log10(x)
print(y)

print(logar)

plt.plot(logar,y,'ro')
# Out:
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.5399 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.3073 seconds
# Counting interfaces...  Done in 0.0361 seconds
# Correcting interface arrays for consistency...
# too much Q 12
# too few P -4
# too few K -4
# too few B -2
# too few O -1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2332 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.4995 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.0916 seconds
# Counting interfaces...  Done in 0.0334 seconds
# Correcting interface arrays for consistency...
# too much Q 25
# too few P -7
# too few K -8
# too few B -3
# too few O -4
# too few A -3
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2286 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 3.6312 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.0853 seconds
# Counting interfaces...  Done in 0.0367 seconds
# Correcting interface arrays for consistency...
# too much Q 8
# too few P -7
# too few K -1
# all good B 0
# all good O 0
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2176 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 22.4921 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.3417 seconds
# Counting interfaces...  Done in 0.0368 seconds
# Correcting interface arrays for consistency...
# too much Q 3
# too few P -3
# too few K -1
# all good B 0
# too much O 1
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2406 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.5723 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.4600 seconds
# Counting interfaces...  Done in 0.0362 seconds
# Correcting interface arrays for consistency...
# too much Q 3
# all good P 0
# all good K 0
# too few B -1
# too few O -1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2329 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.4852 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.5511 seconds
# Counting interfaces...  Done in 0.0359 seconds
# Correcting interface arrays for consistency...
# too much Q 19
# too few P -9
# too few K -7
# too few B -2
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2316 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.6393 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.3013 seconds
# Counting interfaces...  Done in 0.0362 seconds
# Correcting interface arrays for consistency...
# too much Q 1
# all good P 0
# too few K -1
# too much B 1
# too few O -1
# all good A 0
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2314 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.6791 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.4136 seconds
# Counting interfaces...  Done in 0.0367 seconds
# Correcting interface arrays for consistency...
# too much Q 7
# too few P -4
# too few K -2
# too much B 1
# too few O -1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2305 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.5941 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.6407 seconds
# Counting interfaces...  Done in 0.0371 seconds
# Correcting interface arrays for consistency...
# too much Q 10
# too few P -3
# too few K -4
# too few B -2
# all good O 0
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2348 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.5308 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.4979 seconds
# Counting interfaces...  Done in 0.0383 seconds
# Correcting interface arrays for consistency...
# too much Q 12
# too few P -3
# too few K -9
# all good B 0
# too much O 1
# too few A -1
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2332 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# ---SedGen model initialization started---
#
# Initializing modal mineralogy...
# Initializing csds...
# Initializing bins...
# Simulating mineral occurences... |Q|P|K|B|O|A| Done in 1.5163 seconds
# Initializing interfaces... |Q|P|K|B|O|A| Done in 3.3511 seconds
# Counting interfaces...  Done in 0.0356 seconds
# Correcting interface arrays for consistency...
# too much Q 16
# too few P -6
# too few K -4
# too few B -1
# too few O -3
# too few A -2
# Initializing crystal size array... |Q|P|K|B|O|A| Done in 0.2316 seconds
# Initializing inter-crystal breakage probability arrays...
# Initializing model evolution arrays...
#
# ---SedGen model initialization finished succesfully---
# [1.05470837 1.0001357  1.00005224 1.00003296 1.00022269 1.00013818
#  1.0001751  1.00012242 1.00013756 1.00007005 1.00010773]
# [2.         3.         4.         5.         2.39794001 2.54406804
#  2.65321251 2.74036269 2.81291336 2.87506126 2.92941893]
